# %%
import seaborn as sns
import pandas as pd

# %% [markdown]
# #### Que 1: Name any five plots that we can plot using the Seaborn library. Also, state the uses of each plot.

# %% [markdown]
# Ans: We can plot many plots using seaborn library. Some examples of such plots are
#
# a) lineplot
#
# b) scatter plot
#
# c) distplot
#
# d) bar plot
#
# e) pair plot

# %% [markdown]
# #### Que 2: Load the "fmri" dataset using the load_dataset function of seaborn. Plot a line plot using x = "timepoint" and y = "signal" for different events and regions.
# Note:  timepoint, signal, event, and region are columns in the fmri dataset.

# %%
df = pd.read_csv('fmri.csv')

# %%
df.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.lineplot(x = df.timepoint, y = df.signal, data = df, hue = df.event)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(x = df.timepoint, y= df.signal , data = df, hue = df.region)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %% [markdown]
# #### Que 3: Load the "titanic" dataset using the load_dataset function of seaborn. Plot two box plots using x = 'pclass', y = 'age' and y = 'fare'.
#
# Note:  pclass, age, and fare are columns in the titanic dataset.

# %%
df1 = sns.load_dataset('titanic')

# %%
df1.head(2)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class
# 0         0       3    male  22.0      1      0   7.2500        S  Third  \
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False

# %%
sns.boxplot(x = df1.pclass, y = df1.age, data = df1)
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
sns.boxplot(x = df1.pclass, y = df1.fare)
# Out:
# <Axes: xlabel='pclass', ylabel='fare'>

# %% [markdown]
# #### Que 4: Use the "diamonds" dataset from seaborn to plot a histogram for the 'price' column. Use the hue parameter for the 'cut' column of the diamonds dataset.

# %%
df2 = pd.read_csv('diamonds.csv')
df2.head(2)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31

# %%
sns.histplot(x = df2.price, hue = df2.cut.value_counts().groupby)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %% [markdown]
# #### Que 5: Use the "iris" dataset from seaborn to plot a pair plot. Use the hue parameter for the "species" column of the iris dataset.

# %%
df3 = sns.load_dataset('iris')
df3.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %%
sns.scatterplot(x = df3.sepal_length, y = df3.petal_length, hue = df3.species)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# #### Que 6: Use the "flights" dataset from seaborn to plot a heatmap

# %%
df4 = pd.read_csv('flights.csv')

# %%
df4.head(2)
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118

# %%
sns.heatmap(df4[['year', 'passengers']])
# Out:
# <Axes: >
